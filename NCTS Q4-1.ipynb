# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=83768&md5_url=67d19a0367a98c7ac75c78779430abd2')

# %%
df.head()
# Out:
#         季度  買賣移轉案件數_件  土地移轉筆數_筆  建物移轉棟數_棟  公寓平均單價_萬元-坪  華廈平均單價_萬元-坪  \
# 0  101年第4季      124.0     261.0     188.0          6.3          6.4
# 1  102年第1季      154.0     304.0     173.0          6.0          7.0
# 2  102年第2季      130.0     271.0     163.0          9.6          6.8
# 3  102年第3季      136.0     324.0     174.0          0.0          8.9
# 4  102年第4季       88.0     251.0     160.0          6.3          5.6
#
#    住宅大樓平均單價_萬元-坪  透天厝平均總價_萬元-坪  \
# 0            6.7         865.8
# 1           13.3        1214.7
# 2           11.6        1187.8
# 3            9.6        1505.6
# 4           11.6        1481.0
#
#                                           實價登錄價格動態分析
# 0  本季成交量受實價登錄影響較上一季減少，型態仍以商業辦公室居多，集中於民權路中華路一帶，其中又...
# 1  本季因柳川西路上新完工之大樓陸續售出影響，對外提供查詢之買賣實價案件計154件，較上季增加3...
# 2  本季因新完工之大樓交易減緩之影響，對外提供查詢之買賣實價案件計130件，較上季減少24件，減...
# 3  本季因新完工之大樓交易減緩之影響，對外提供查詢之買賣實價案件計136件，較上季增加6件，增加...
# 4  本季交易量因無新建案移轉，對外提供查詢之買賣實價案件計88件，較上季減少48件，減少幅度為3...

# %%
import matplotlib as mpl
# 如何在Win 10解決matplotlib中文顯示的問題? https://daxpowerbi.com/%E5%A6%82%E4%BD%95%E5%9C%A8win-10%E8%A7%A3%E6%B1%BAmatplotlib%E4%B8%AD%E6%96%87%E9%A1%AF%E7%A4%BA%E7%9A%84%E5%95%8F%E9%A1%8C/
mpl.rc('font', family='Noto Sans CJK TC')

import matplotlib 
matplotlib.matplotlib_fname()

# %%
df1 = df.loc[0:21,'季度':'透天厝平均總價_萬元-坪'].copy()
df2 = df1.sort_values(by = ['季度'], ascending=True)
df2.plot.bar(x='季度', y=['公寓平均單價_萬元-坪', '華廈平均單價_萬元-坪', '住宅大樓平均單價_萬元-坪'])

# %%
df2.plot(x='季度', y=['公寓平均單價_萬元-坪', '華廈平均單價_萬元-坪', '住宅大樓平均單價_萬元-坪'])
